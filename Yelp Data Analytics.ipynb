# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Palash\\Desktop\\Python Programming course'

# %%
import json
from pandas import DataFrame
business_file = 'business.json'
business_records = [json.loads(line) for line in open(business_file)]
business_data_frame = DataFrame(business_records)

column = 'stars'
business_counts = business_data_frame.groupby(column).size()

print (business_counts)

##print counts
# Out:
# stars
# 1.0     2733
# 1.5     3516
# 2.0     8331
# 2.5    13730
# 3.0    21815
# 3.5    28610
# 4.0    31529
# 4.5    22557
# 5.0    23818
# dtype: int64

# %%
#listing various attributes
from pandas import DataFrame
business_file = 'business.json'
business_records = [json.loads(line) for line in open(business_file)]
business_data_frame = DataFrame(business_records)

column = 'city'
business_attributes = business_data_frame.city

print (business_attributes)
# Out:
# 0         Richmond Heights
# 1                Charlotte
# 2                  Toronto
# 3               Scottsdale
# 4                  Phoenix
# 5                  Phoenix
# 6                  Phoenix
# 7               Pittsburgh
# 8                 McMurray
# 9                  Gilbert
# 10               Las Vegas
# 11              Scottsdale
# 12                    Mesa
# 13                Avondale
# 14                Matthews
# 15                 Stanley
# 16                    Mesa
# 17               Cleveland
# 18               Cleveland
# 19               Las Vegas
# 20               Pineville
# 21              Pittsburgh
# 22             Mississauga
# 23                 Gilbert
# 24                    Mesa
# 25               Edinburgh
# 26                 Toronto
# 27                Montréal
# 28              Pittsburgh
# 29              Scottsdale
#                 ...
# 156609               Tempe
# 156610           Las Vegas
# 156611           Las Vegas
# ...

# %%
from pandas import DataFrame
business_file = 'business.json'
business_records = [json.loads(line) for line in open(business_file)]
business_data_frame = DataFrame(business_records)

#column = column[1:10]
business_df = business_data_frame.columns[1:5]

print (business_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-60e5540a93eb> in <module>()
#       1 from pandas import DataFrame
#       2 business_file = 'business.json'
# ----> 3 business_records = [json.loads(line) for line in open(business_file)]
#       4 business_data_frame = DataFrame(business_records)
#       5
#
# <ipython-input-2-60e5540a93eb> in <listcomp>(.0)
#       1 from pandas import DataFrame
#       2 business_file = 'business.json'
# ----> 3 business_records = [json.loads(line) for line in open(business_file)]
#       4 business_data_frame = DataFrame(business_records)
#       5
#
# NameError: name 'json' is not defined

# %%
from pandas import DataFrame
business_file = 'business.json'
business_records = [json.loads(line) for line in open(business_file)]
business_data_frame = DataFrame(business_records)

#column = column[1:10]
business_df = business_data_frame

print (business_df)
# Out:
#                                            address  \
# 0                                  691 Richmond Rd
# 1                                   2824 Milton Rd
# 2                              337 Danforth Avenue
# 3              7702 E Doubletree Ranch Rd, Ste 300
# 4                                   4719 N 20Th St
# 5                              2017 E Camelback Rd
# 6                          4425 N 24th St, Ste 125
# 7                                   5770 Butler St
# 8                               3220 Washington Rd
# 9                        1425 S Higley Rd, Ste 103
# 10                         11022 W Charleston Blvd
# 11                         9393 N 90th St, Ste 112
# 12                              9101 E Baseline Rd
# 13                                 12417 W Pima St
# 14                        9616 E Independence Blvd
# 15                                 190 E Dallas Rd
# 16                                        62 S Ctr
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Palash\\Desktop\\Python Programming course'

# %%
import csv
import json
# import unicode_literals

output = csv.writer(open('business.csv','w',encoding='utf-8'))
#output.writerow(["business_id","name","neighborhood", "address","city","state","postal_code","latitude","longitude","stars","review_count","is-open","attributes","categories","hours"])
with open ('business.json','r', encoding='utf-8') as jsonfile:
    for line in jsonfile:
        row = json.loads(line)
        output.writerow(row.values())

# %%
import pandas as pd
df = pd.read_csv('business.csv')

df = df.head()
print (df)

# %%
df[1:6]

# %%
df.info()

# %%
df.describe()

# %%
df.columns = df []

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = 8,4

# %%
w = sns.barplot (data = df, x = 'review_count', y = 'stars')

# %%
a = w = sns.barplot (data = df, x = 'review_count', y = 'categories')

# %%
s1 = sns.distplot(df.stars, bins = 15)

# %%
data = df.groupby(['postal_code', 'state','city'])['business_id'].max()
#df[df.state == 'AZ']
data

# %%
import csv
import json
# import unicode_literals

output = csv.writer(open('review1.csv','w',encoding ="utf-8"))
output.writerow(["review_id", "business_id","user_id", "date", "text", "A","stars","B", "C"])
with open ('C://Users//Palash//Desktop//Python Programming course//review.json','r', encoding = 'utf-8') as jsonfile:
    for line in jsonfile:
        row = json.loads(line)
        output.writerow(row.values())

# %%
import pandas as pd

df3 = pd.read_csv("review1.csv")

df3.columns = ['stars', 'A', 'B','user_id','business_id','review_id','text','date','C']

df3.head()
# Out:
#    stars  A  B                 user_id             business_id  \
# 0      5  0  0  cjpdDjZyprfyDG3RlkVG3w  uYHaNptLzDLoV_JZ_MuzUA
# 1      3  0  0  bjTcT8Ty4cJZhEOEo01FGA  uYHaNptLzDLoV_JZ_MuzUA
# 2      3  0  0  AXgRULmWcME7J6Ix3I--ww  uYHaNptLzDLoV_JZ_MuzUA
# 3      4  0  0  oU2SSOmsp_A8JYI7Z2JJ5w  uYHaNptLzDLoV_JZ_MuzUA
# 4      5  0  0  0xtbPEna2Kei11vsU-U2Mw  uYHaNptLzDLoV_JZ_MuzUA
#
#                 review_id                                               text  \
# 0  VfBHSwC5Vz_pbFluy07i9Q  My girlfriend and I stayed here for 3 nights a...
# 1  3zRpneRKDsOPq92tq7ybAA  If you need an inexpensive place to stay for a...
# 2  ne5WhI1jUFOcRn-b-gAzHA  Mittlerweile gibt es in Edinburgh zwei Ableger...
# 3  llmdwOgDReucVoWEry61Lw  Location is everything and this hotel has it! ...
# 4  DuffS87NaSMDmIfluvT83g  gute lage im stadtzentrum. shoppingmeile und s...
#
#          date  C
# 0  2016-07-12  0
# 1  2016-10-02  0
# 2  2015-09-17  0
# 3  2016-08-21  0
# 4  2013-11-20  0

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Palash\\Desktop\\Python Programming course'

# %%
data = df3

# %%
data['text length'] = data['text'].apply(len)
data.head()
# Out:
#    stars  A  B                 user_id             business_id  \
# 0      5  0  0  cjpdDjZyprfyDG3RlkVG3w  uYHaNptLzDLoV_JZ_MuzUA
# 1      3  0  0  bjTcT8Ty4cJZhEOEo01FGA  uYHaNptLzDLoV_JZ_MuzUA
# 2      3  0  0  AXgRULmWcME7J6Ix3I--ww  uYHaNptLzDLoV_JZ_MuzUA
# 3      4  0  0  oU2SSOmsp_A8JYI7Z2JJ5w  uYHaNptLzDLoV_JZ_MuzUA
# 4      5  0  0  0xtbPEna2Kei11vsU-U2Mw  uYHaNptLzDLoV_JZ_MuzUA
#
#                 review_id                                               text  \
# 0  VfBHSwC5Vz_pbFluy07i9Q  My girlfriend and I stayed here for 3 nights a...
# 1  3zRpneRKDsOPq92tq7ybAA  If you need an inexpensive place to stay for a...
# 2  ne5WhI1jUFOcRn-b-gAzHA  Mittlerweile gibt es in Edinburgh zwei Ableger...
# 3  llmdwOgDReucVoWEry61Lw  Location is everything and this hotel has it! ...
# 4  DuffS87NaSMDmIfluvT83g  gute lage im stadtzentrum. shoppingmeile und s...
#
#          date  C  text length
# 0  2016-07-12  0         1150
# 1  2016-10-02  0          902
# ...

# %%
data.tail()
# Out:
#          stars  A  B                 user_id             business_id  \
# 4736884      5  1  1  SGgO8dvXq1GOL58jFtULhA  iJ4uoZkPNJ39Vfh0HirI3w
# 4736885      2  0  0  3roAGe7soqSOB5FVIcqO-Q  iJ4uoZkPNJ39Vfh0HirI3w
# 4736886      4  3  1  FAjCZoxiGw9HJKueB8YWTg  iJ4uoZkPNJ39Vfh0HirI3w
# 4736887      4  0  0  -Kv9DMBZGQyf2WSKDR7LwA  iJ4uoZkPNJ39Vfh0HirI3w
# 4736888      5  0  0  jFCt0lMNjo0obGjVXVHYUg  iJ4uoZkPNJ39Vfh0HirI3w
#
#                       review_id  \
# 4736884  WxEo3E-7nDzPAwRip828QA
# 4736885  RyWg5rJMd4_QBsItEFXFHA
# 4736886  -Kj48AkzcOz6N6uVMlVe_w
# 4736887  932NZmVXVvZa5UlAet6F-Q
# 4736888  m-4DuIwMOJ0vNdqGrKRGJw
#
#                                                       text        date  C  \
# 4736884  Never had Ramen and Noodles but my friend want...  2015-06-29  2
# 4736885  There are plenty of good Ramen houses in Vegas...  2015-09-11  0
# 4736886  This place reminds me of a ramen house in Waik...  2015-08-30  1
# ...

# %%
data.describe()
# Out:
#               stars             A             B             C   text length
# count  4.736889e+06  4.736889e+06  4.736889e+06  4.736889e+06  4.736889e+06
# mean   3.724048e+00  9.882917e-01  4.029166e-01  5.096600e-01  6.225444e+02
# std    1.421104e+00  2.600023e+00  1.721955e+00  1.960375e+00  5.807340e+02
# min    1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# 25%    3.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  2.450000e+02
# 50%    4.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  4.420000e+02
# 75%    5.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  7.960000e+02
# max    5.000000e+00  1.125000e+03  6.310000e+02  5.130000e+02  5.212000e+03

# %%
data.columns
# the total rows are 3137531 rows x 9 columns
total_rows = data.count
print (total_rows) + 1
# Out:
# <bound method DataFrame.count of                       review_id  stars  A  B        Date  C  \
# 0        VfBHSwC5Vz_pbFluy07i9Q      5  0  0  2016-07-12  0
# 1        3zRpneRKDsOPq92tq7ybAA      3  0  0  2016-10-02  0
# 2        ne5WhI1jUFOcRn-b-gAzHA      3  0  0  2015-09-17  0
# 3        llmdwOgDReucVoWEry61Lw      4  0  0  2016-08-21  0
# 4        DuffS87NaSMDmIfluvT83g      5  0  0  2013-11-20  0
# 5        GvLmUkjUrOyFH8KFnmT1uw      5  0  0  2016-06-05  0
# 6        lGEl24NGj2HVBJrodeXcjg      4  0  0  2015-02-21  0
# 7        cUgvEy5wj7zYE68v1BzzVg      4  0  0  2013-07-07  0
# 8        FSB_BnvysBgH3JYrbFNcgw      4  2  0  2013-04-27  2
# 9        dhl3ZW9aAEX_T7_um5tfaQ      4  0  0  2015-04-13  2
# 10       JQJvnM3p-3eML05eKcTgiw      4  1  1  2016-11-08  1
# 11       6JF4WfHgwYrrdZ2VeYtnFw      3  0  0  2015-07-27  1
# 12       fbVYETRuWDw8QnpimpGMpg      4  0  0  2014-05-07  1
# 13       lobj38NgaokqVseN8_nn6g      4  0  0  2015-02-26  1
# ...

# %%
#print (df3[:3]) -- prints all the data from first row till second ie 0,1,2

# %%
import os
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
import nltk
# %matplotlib inline
pd.options.display.mpl_style = 'default'

#pd.set_option('display.max_columns', 36)
#print pd.__version__
# Out:
# C:\Users\Palash\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2881: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
import numpy as np
N_star_categories = 5
colors = np.array(['#660000', '#ff4d4d', '#ffb3b3', '#99e699', '#29a329']) # 1, 2, 3, 4, and 5 stars respectively

# %%
stars_labels = np.array(range(N_star_categories)) + 1;
star_category_dist_fig = plt.figure(figsize=(12,8))
bar_plot_indices = np.arange(N_star_categories) 
star_category_absolute_frequencies = dataA.stars.value_counts(ascending=True);
star_category_relative_frequencies = np.array(star_category_absolute_frequencies)/float(sum(star_category_absolute_frequencies))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
sns.set(style="white")
plt.figure(figsize=(12, 8))
ax = sns.barplot(x=bar_plot_indices + 1, y=star_category_relative_frequencies)
ax.set_xlabel('Star Category');
ax.set_ylabel('Relative Frequency');
ax.set_title('Star Category Distribution for {0} Reviews'.format(len(dataA)));
#py.iplot_mpl(fig2, strip_style = True)

# %%
#to find out if there’s any relationship between our newly created text length feature and the stars rating.

import seaborn as sns
df3=dataA
g = sns.FacetGrid(data=df3, col='stars')
g.map(plt.hist, 'text length', bins=50)

# %%
sns.boxplot(x='stars', y='text length', data=df3yelp_class = yelp[(yelp['stars'] == 1) | (yelp['stars'] == 5)]
yelp_class.shape)
# Out:
#   File "<ipython-input-18-15aca772212f>", line 1
#     sns.boxplot(x='stars', y='text length', data=df3yelp_class = yelp[(yelp['stars'] == 1) | (yelp['stars'] == 5)]
#                                                                ^
# SyntaxError: invalid syntax

# %%
yelp_class = df3[(df3['stars'] == 1) | (df3['stars'] == 5)]
yelp_class.shape
# Out:
# (5099, 10)

# %%
# FOR INSTALLING Word cloud go to anaconda prompt stop the operations using ctrl+c then copy passte this "conda install -c https://conda.anaconda.org/conda-forge wordcloud"
import os
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
#Convert all the required text into a single string here 
#and store them in word_string

#you can specify fonts, stopwords, background color and other options
def plot_word_cloud(data):
    wordcloud = WordCloud(max_font_size=40, relative_scaling=.5).generate(str(data))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
plot_word_cloud(df3["text"].loc[df3.stars == 1, ])

# %%
from sklearn.feature_extraction.text import TfidfTransformer
>>> transformer = TfidfTransformer(smooth_idf=False)
>>> transformer
# Out:
# TfidfTransformer(norm='l2', smooth_idf=False, sublinear_tf=False,
#          use_idf=True)

# %%
plot_word_cloud(df3["text"].loc[df3.stars == 2, ])

# %%
plot_word_cloud(df3["text"].loc[df3.stars == 3, ])

# %%
plot_word_cloud(df3["text"].loc[df3.stars == 4, ])

# %%
plot_word_cloud(df3["text"].loc[df3.stars == 5, ])

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = 8,4
sns.set_style("whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(11.7,8.27)
h = plt.hist(df3.stars, bins = 30, stacked = True, rwidth = 1)
plt.title("Stars Distribution", fontsize = 35, color="DarkBlue")

plt.ylabel("No. of Reviews", fontsize = 25, color = "Red")
plt.xlabel("Stars", fontsize = 25, color = "Green")
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(frameon = True, fancybox = True, shadow = True, framealpha = 1)
plt.show()

# %%
df3.ix[0]
# Out:
# stars                                                          5
# A                                                              0
# review_id                                 VfBHSwC5Vz_pbFluy07i9Q
# B                                                              0
# business_id                               uYHaNptLzDLoV_JZ_MuzUA
# text           My girlfriend and I stayed here for 3 nights a...
# user_id                                   cjpdDjZyprfyDG3RlkVG3w
# C                                                              0
# Date                                                  2016-07-12
# text length                                                 1154
# Name: 0, dtype: object

# %%
df3.ix[0,'text']
# Out:
# 'My girlfriend and I stayed here for 3 nights and loved it. The location of this hotel and very decent price makes this an amazing deal. When you walk out the front door Scott Monument and Princes street are right in front of you, Edinburgh Castle and the Royal Mile is a 2 minute walk via a close right around the corner, and there are so many hidden gems nearby including Calton Hill and the newly opened Arches that made this location incredible.\r\n\r\nThe hotel itself was also very nice with a reasonably priced bar, very considerate staff, and small but comfortable rooms with excellent bathrooms and showers. Only two minor complaints are no telephones in room for room service (not a huge deal for us) and no AC in the room, but they have huge windows which can be fully opened. The staff were incredible though, letting us borrow umbrellas for the rain, giving us maps and directions, and also when we had lost our only UK adapter for charging our phones gave us a very fancy one for free
# ...

# %%
data = df3[(df3['stars'] >=2 ) & (df3 ['stars'] <=3)]
data.head()
# Out:
#     stars  A  B                 user_id             business_id  \
# 1       3  0  0  bjTcT8Ty4cJZhEOEo01FGA  uYHaNptLzDLoV_JZ_MuzUA
# 2       3  0  0  AXgRULmWcME7J6Ix3I--ww  uYHaNptLzDLoV_JZ_MuzUA
# 11      3  1  0  Q-3YCVywc03w56wYtGlKvg  uYHaNptLzDLoV_JZ_MuzUA
# 15      3  1  0  IpLZ7RevQrFPJWYc9Gxymg  uYHaNptLzDLoV_JZ_MuzUA
# 19      3  1  1  Ji9PeffxjwqPLO7pEfSpKQ  jQsNFOzDpxPmOurSWCg1vQ
#
#                  review_id                                               text  \
# 1   3zRpneRKDsOPq92tq7ybAA  If you need an inexpensive place to stay for a...
# 2   ne5WhI1jUFOcRn-b-gAzHA  Mittlerweile gibt es in Edinburgh zwei Ableger...
# 11  6JF4WfHgwYrrdZ2VeYtnFw  Stayed here for two nights, costs was £109 per...
# 15  OF1ToqGAubsWGri5iad15w  Had Continental style breakfast here a short d...
# 19  G-EFA005besj5uHsH0sQFA  I'm not saying Pei Wei is the best asian food ...
#
#           date  C
# 1   2016-10-02  0
# 2   2015-09-17  0
# 11  2015-07-27  0
# 15  2013-12-07  0
# ...

# %%
df3.shape
# Out:
# (4736889, 10)

# %%
X = data.text
y = data.stars

# %%
X.shape
# Out:
# (2325,)

# %%
import statistics
items = df3.stars
statistics.median(items)
# Out:
# 4

# %%
#text cleaning
df3['text'][0]
# Out:
# 'My girlfriend and I stayed here for 3 nights and loved it. The location of this hotel and very decent price makes this an amazing deal. When you walk out the front door Scott Monument and Princes street are right in front of you, Edinburgh Castle and the Royal Mile is a 2 minute walk via a close right around the corner, and there are so many hidden gems nearby including Calton Hill and the newly opened Arches that made this location incredible.\r\n\r\nThe hotel itself was also very nice with a reasonably priced bar, very considerate staff, and small but comfortable rooms with excellent bathrooms and showers. Only two minor complaints are no telephones in room for room service (not a huge deal for us) and no AC in the room, but they have huge windows which can be fully opened. The staff were incredible though, letting us borrow umbrellas for the rain, giving us maps and directions, and also when we had lost our only UK adapter for charging our phones gave us a very fancy one for free
# ...

# %%
import re
review = re.sub('[^a-zA-Z]',' ', df3['text'][0])

# %%
review
# Out:
# 'My girlfriend and I stayed here for   nights and loved it  The location of this hotel and very decent price makes this an amazing deal  When you walk out the front door Scott Monument and Princes street are right in front of you  Edinburgh Castle and the Royal Mile is a   minute walk via a close right around the corner  and there are so many hidden gems nearby including Calton Hill and the newly opened Arches that made this location incredible     The hotel itself was also very nice with a reasonably priced bar  very considerate staff  and small but comfortable rooms with excellent bathrooms and showers  Only two minor complaints are no telephones in room for room service  not a huge deal for us  and no AC in the room  but they have huge windows which can be fully opened  The staff were incredible though  letting us borrow umbrellas for the rain  giving us maps and directions  and also when we had lost our only UK adapter for charging our phones gave us a very fancy one for free    
# ...

# %%
review = review.lower()

# %%
review
# Out:
# 'my girlfriend and i stayed here for   nights and loved it  the location of this hotel and very decent price makes this an amazing deal  when you walk out the front door scott monument and princes street are right in front of you  edinburgh castle and the royal mile is a   minute walk via a close right around the corner  and there are so many hidden gems nearby including calton hill and the newly opened arches that made this location incredible     the hotel itself was also very nice with a reasonably priced bar  very considerate staff  and small but comfortable rooms with excellent bathrooms and showers  only two minor complaints are no telephones in room for room service  not a huge deal for us  and no ac in the room  but they have huge windows which can be fully opened  the staff were incredible though  letting us borrow umbrellas for the rain  giving us maps and directions  and also when we had lost our only uk adapter for charging our phones gave us a very fancy one for free    
# ...

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Palash\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
review.split()
# Out:
# ['my',
#  'girlfriend',
#  'and',
#  'i',
#  'stayed',
#  'here',
#  'for',
#  'nights',
#  'and',
#  'loved',
#  'it',
#  'the',
#  'location',
#  'of',
#  'this',
#  'hotel',
#  'and',
#  'very',
#  'decent',
#  'price',
#  'makes',
#  'this',
#  'an',
#  'amazing',
#  'deal',
#  'when',
#  'you',
#  'walk',
#  'out',
#  'the',
#  'front',
#  'door',
#  'scott',
#  'monument',
#  'and',
#  'princes',
#  'street',
#  'are',
#  'right',
#  'in',
#  'front',
#  'of',
#  'you',
#  'edinburgh',
#  'castle',
#  'and',
#  'the',
#  'royal',
#  'mile',
#  'is',
#  'a',
#  'minute',
#  'walk',
#  'via',
#  'a',
#  'close',
#  'right',
#  'around',
#  'the',
#  'corner',
#  'and',
#  'there',
#  'are',
#  'so',
#  'many',
#  'hidden',
#  'gems',
#  'nearby',
#  'including',
#  'calton',
#  'hill',
#  'and',
#  'the',
#  'newly',
#  'opened',
#  'arches',
#  'that',
#  'made',
#  'this',
#  'location',
#  'incredible',
#  'the',
#  'hotel',
#  'itself',
#  'was',
#  'also',
#  'very',
# ...

# %%
from nltk.corpus import stopwords
review = [word for word in review if not word in set(stopwords.words('english'))]

# %%
review.join()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-6420d8507969> in <module>()
# ----> 1 review.join()
#
# AttributeError: 'list' object has no attribute 'join'

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]

# %%
review
# Out:
# [' ',
#  'g',
#  'r',
#  'l',
#  'f',
#  'r',
#  'e',
#  'n',
#  ' ',
#  'n',
#  ' ',
#  ' ',
#  'e',
#  ' ',
#  'h',
#  'e',
#  'r',
#  'e',
#  ' ',
#  'f',
#  'r',
#  ' ',
#  ' ',
#  ' ',
#  'n',
#  'g',
#  'h',
#  ' ',
#  'n',
#  ' ',
#  'l',
#  'v',
#  'e',
#  ' ',
#  ' ',
#  ' ',
#  'h',
#  'e',
#  ' ',
#  'l',
#  'c',
#  'n',
#  ' ',
#  'f',
#  ' ',
#  'h',
#  ' ',
#  'h',
#  'e',
#  'l',
#  ' ',
#  'n',
#  ' ',
#  'v',
#  'e',
#  'r',
#  ' ',
#  'e',
#  'c',
#  'e',
#  'n',
#  ' ',
#  'p',
#  'r',
#  'c',
#  'e',
#  ' ',
#  'k',
#  'e',
#  ' ',
#  'h',
#  ' ',
#  'n',
#  ' ',
#  'z',
#  'n',
#  'g',
#  ' ',
#  'e',
#  'l',
#  ' ',
#  ' ',
#  'w',
#  'h',
#  'e',
#  'n',
#  ' ',
#  'u',
#  ' ',
#  'w',
#  'l',
#  'k',
#  ' ',
#  'u',
#  ' ',
#  'h',
#  'e',
#  ' ',
#  'f',
#  'r',
#  'n',
#  ' ',
#  'r',
#  ' ',
#  'c',
#  ' ',
#  'n',
#  'u',
#  'e',
#  'n',
#  ' ',
#  'n',
#  ' ',
#  'p',
#  'r',
#  'n',
#  'c',
#  'e',
#  ' ',
#  'r',
#  'e',
#  'e',
#  ' ',
#  'r',
#  'e',
# ...

# %%
review = ' '.join(review)

# %%
review
# Out:
# 'girlfriend stay night love locat hotel decent price make amaz deal walk front door scott monument princ street right front edinburgh castl royal mile minut walk via close right around corner mani hidden gem nearbi includ calton hill newli open arch made locat incred hotel also nice reason price bar consider staff small comfort room excel bathroom shower two minor complaint telephon room room servic huge deal us ac room huge window fulli open staff incred though let us borrow umbrella rain give us map direct also lost uk adapt charg phone gave us fanci one free would highli recommend hotel friend return edinburgh definit stay without hesit'

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y, random_state=1)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)

# %%
#creating bag of words model
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()

# %%
data = df3[["text",'stars']]

# %%
data.head()
# Out:
#                                                 text  stars
# 0  My girlfriend and I stayed here for 3 nights a...      5
# 1  If you need an inexpensive place to stay for a...      3
# 2  Mittlerweile gibt es in Edinburgh zwei Ableger...      3
# 3  Location is everything and this hotel has it! ...      4
# 4  gute lage im stadtzentrum. shoppingmeile und s...      5

# %%
data.count()
# Out:
# text     4736889
# stars    4736889
# dtype: int64

# %%
data.stars.value_counts()
# Out:
# 5    1987999
# 4    1135829
# 1     639848
# 3     570818
# 2     402395
# Name: stars, dtype: int64

# %%
data.sort_values(by='stars')
# Out:
#                                                       text  stars
# 2053359  Quality of the food aside, here's the biggest ...      1
# 537509   The lady/owner was exteremly attentive and alm...      1
# 537510   I bought a pair of shoes here for a Christmas ...      1
# 1318791  I went there mid afternoon today and stood at ...      1
# 4191574  This is the 2nd time we've been here in 5 mont...      1
# 4191575  Poorly managed restaurant. I have been to John...      1
# 2518834  Please read my original review dated 1/16/2015...      1
# 3482030  Won't be coming back nor buying groupons for t...      1
# 4514476  This place is so overrated!!  I'm concerned th...      1
# 1318793  Bland bland bland! Overpriced garbage. I see w...      1
# 2518836  i agree with the review from cody.  beware of ...      1
# 2518839  Don't go, but if you do, don't talk to John or...      1
# 4191579  I got sick from the food, it was not worth the...      1
# ...

# %%
import statistics
med = statistics.median(data.stars)

# %%
med
# Out:
# 4

# %%
data.tail()
# Out:
#                                                       text  stars
# 4736884  Never had Ramen and Noodles but my friend want...      5
# 4736885  There are plenty of good Ramen houses in Vegas...      2
# 4736886  This place reminds me of a ramen house in Waik...      4
# 4736887  It's interesting concept to eat Japanese ramen...      4
# 4736888  First of all, I love ramen and I live in a cit...      5

# %%
data["review"]= data.stars.map({5:+1,4:+1,3:-1,2:-1,1:-1})
# Out:
# D:\Python\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#                                                       text  stars  review
# 0        My girlfriend and I stayed here for 3 nights a...      5       1
# 1        If you need an inexpensive place to stay for a...      3      -1
# 2        Mittlerweile gibt es in Edinburgh zwei Ableger...      3      -1
# 3        Location is everything and this hotel has it! ...      4       1
# 4        gute lage im stadtzentrum. shoppingmeile und s...      5       1
# 5        Erstklassige Lage. Dazu ist alles geschrieben ...      5       1
# 6        Beautiful space, great location, staff rock. T...      4       1
# 7        This is a fairly new property I think. It is a...      4       1
# 8        First time at this group of hotels. Pretty new...      4       1
# 9        Location location location! \n\nMotel One is j...      4       1
# 10       A hotel that has all the basics that you'd nee...      4       1
# 11       Stayed here for two nights, costs was £109 per...      3      -1
# ...

# %%
data.review.value_counts()
# Out:
#  1    3123828
# -1    1613061
# Name: review, dtype: int64

# %%
x= data.text
y= data.review
print(x.shape)
print(y.shape)
# Out:
# (4736889,)
# (4736889,)

# %%
from sklearn.cross_validation import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x, y, random_state=1)
# Out:
# D:\Python\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3552666,)
# (1184223,)
# (3552666,)
# (1184223,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vect= TfidfVectorizer(min_df=1, stop_words='english')

# %%
vect.fit(x_train)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
x_train_dtm= vect.transform(x_train)
x_train_dtm
# Out:
# <3552666x595584 sparse matrix of type '<class 'numpy.float64'>'
# 	with 155602224 stored elements in Compressed Sparse Row format>

# %%
x_test_dtm= vect.transform(x_test)
x_test_dtm
# Out:
# <1184223x595584 sparse matrix of type '<class 'numpy.float64'>'
# 	with 51732467 stored elements in Compressed Sparse Row format>

# %%
from sklearn.naive_bayes import MultinomialNB
nb= MultinomialNB()

# %%
nb.fit(x_train_dtm, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
y_predict_class= nb.predict(x_test_dtm)

# %%
y_predict_class
# Out:
# array([ 1, -1, -1, ..., -1,  1,  1], dtype=int64)

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_predict_class)
# Out:
# 0.84876159304455323

# %%
metrics.confusion_matrix(y_test, y_predict_class)
# Out:
# array([[252294, 150383],
#        [ 28720, 752826]])

# %%
# fit: Learn the vocabulary of the text data 
vect.fit(x)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
# Uses a fitted vocabulary to build a document term matrix from the text data.

x_dtm= vect.transform(x)

# %%
# 1. Split the dataset into K equal partitions.
# 2. Use fold 1 as the testing set and the union of the other folds as the training set.
# 3. Calculate testing accuracy.
# 4. Repeat step 2 and 3 K times, using a different fold as the testing set each time.
# 5. Use the average testing accuracy.

from sklearn.cross_validation import cross_val_score

# %%
# number of folds are 5
# nb= Multinamial Naive Bayes is used to fit x_dtm and y

scores= cross_val_score(nb, x_dtm, y, cv=5, scoring='accuracy')
scores

# %%
# mean of all the accuracies

scores.mean()

# %%
scores= cross_val_score(nb, x_dtm, y, cv=10, scoring='accuracy')
scores
# Out:
# array([ 0.84741286,  0.84426069,  0.84648366,  0.84544501,  0.84820842,
#         0.85000074,  0.85070162,  0.85071007,  0.84958876,  0.84906943])

# %%
# mean of all the accuracies

scores.mean()
# Out:
# 0.84818812580518532

# %%
range= [5, 10, 15, 20, 25]
optimal_accuracy=[]
for x in range:
    scores= cross_val_score(nb, x_dtm, y, cv=x, scoring='accuracy')
    optimal_accuracy.append(scores.mean())

optimal_accuracy

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vect= TfidfVectorizer(min_df=3, stop_words='english')

# %%
x_dtm = vect.fit_transform(x)

# %%
#x_dtm= vect.transform(x)

# %%
from sklearn.cross_validation import cross_val_score
# Out:
# D:\Python\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn import svm
clf = svm.SVC()

scores = cross_val_score(clf,x_dtm,y,cv = 5, scoring = 'accuracy')
scores

# %%
scores.mean()

# %%
scores = cross_val_score(clf,x_dtm,y,cv = 10, scoring = 'accuracy')
scores

# %%
data['stars'] = (data['stars'] >= 4).astype(int)
# Out:
# C:\Users\Palash\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df1 = data.head(1000)
df1
# Out:
#                                                   text  stars
# 0    My girlfriend and I stayed here for 3 nights a...      1
# 1    If you need an inexpensive place to stay for a...      0
# 2    Mittlerweile gibt es in Edinburgh zwei Ableger...      0
# 3    Location is everything and this hotel has it! ...      1
# 4    gute lage im stadtzentrum. shoppingmeile und s...      1
# 5    Erstklassige Lage. Dazu ist alles geschrieben ...      1
# 6    Beautiful space, great location, staff rock. T...      1
# 7    This is a fairly new property I think. It is a...      1
# 8    First time at this group of hotels. Pretty new...      1
# 9    Location location location! \r\n\r\nMotel One ...      1
# 10   A hotel that has all the basics that you'd nee...      1
# 11   Stayed here for two nights, costs was £109 per...      0
# 12   Well, i like the idea of Motel One. Always in ...      1
# 13   I really do love the Germans. This chain is sp...      1
# ...

# %%
data.stars.value_counts()
# Out:
# 1    3123828
# 0    1613061
# Name: stars, dtype: int64

# %%
import numpy as np

data1 = data.take(np.random.permutation(len(data))[:4000000])
data1
# Out:
#                                                       text  stars
# 1164346  As big and boxy as a big box store can get. Th...      1
# 1596022  I truly love this gym and the people in it. No...      1
# 3855854  The mushroom ravioli was delicious! The servic...      1
# 2083722  Came to this spot looking for Canters Deli but...      0
# 1975857  There's really no way to give such an interest...      1
# 4634610  This Whole Foods felt a lot smaller to me than...      0
# 1927206  LOVED this place. Probably the best non-art mu...      1
# 2874144  Worst drive thru experience ever !!!!!\r\nWors...      0
# 363857   Great food, VERY fresh, worth going. However, ...      1
# 2712973  Wir sind ab und an im Cafe del Sol, meist jedo...      0
# 4620292  One of my best tibetan restaurant from every a...      1
# 1880815  My dogs Oreo and Gizmo have been going to Bev ...      1
# 1200526  Stopped by here quick for a salad bowl. Big an...      1
# ...

# %%
from sklearn.cross_validation import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x, y, random_state=1)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vect= TfidfVectorizer()

# %%
vect.fit(x_train)
x_train_dtm= vect.transform(x_train)

# %%
x_train_dtm
x_test_dtm= vect.transform(x_test)
x_test_dtm
from sklearn.naive_bayes import MultinomialNB
nb= MultinomialNB()
nb.fit(x_train_dtm, y_train)
y_predict_class= nb.predict(x_test_dtm)
y_predict_class
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %%
pred=nb.predict(x_test_dtm[0])
pred
import numpy as np
actual=np.array(y_test)
print(actual)
print(y_predict_class)
# Out:
# [0 1 1 ..., 1 1 1]
# [0 1 1 ..., 1 1 1]

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_predict_class)
# Out:
# 0.85026299999999999

# %%
metrics.confusion_matrix(y_test, y_predict_class)
# Out:
# array([[213251, 127972],
#        [ 21765, 637012]])

# %%
from sklearn.svm import SVC
classifier = SVC()
classifier.fit(x_train_dtm, y_train)

# %%
y_predict_class= nb.predict(x_test_dtm)
y_predict_class

# %%
pred=nb.predict(x_test_dtm[0])
pred
import numpy as np
actual=np.array(y_test)
print(actual)
print(y_predict_class)

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_predict_class)
